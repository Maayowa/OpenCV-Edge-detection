# %% [markdown]
# <a href="https://colab.research.google.com/github/Maayowa/OpenCV-Edge-detection/blob/main/EdgeDetection_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9a8c32c9-7cd0-41cf-83e3-417c39a5d298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a8c32c9-7cd0-41cf-83e3-417c39a5d298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving panda-black-white-study.jpg to panda-black-white-study.jpg
# ...

# %%
from google.colab.patches import cv2_imshow
path = "/content/panda-black-white-study.jpg"

img = cv2.imread(path, 0)

# Using the Canny Edge detector
canny = cv2.Canny(img, 100, 200,)

# Checkout Laplacian Gradient
laplace = cv2.Laplacian(img, cv2.CV_64F)

# Sobel Gradient
sobelx = cv2.Sobel(img, cv2.CV_64F, 1,0, ksize = 5,)
sobely = cv2.Sobel(img, cv2.CV_64F, 0,1, ksize = 5)


sobelxy = cv2.bitwise_or()


for title, img in zip(['img', 'cannydetect', 'laplacedetect', 'sobelx', 'sobely'], [img, canny, laplace, sobelx, sobely]):
  print('\n' + title + ':\n')
  cv2_imshow(img)
# Out:
# img:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDE6D6D0>
# cannydetect:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDE6D850>
# laplacedetect:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDEA1150>
# sobelx:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDEA1C50>
# sobely:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EE2F7B0D0>
